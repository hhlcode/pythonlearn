# %%
from ltp import LTP
import pandas as pd 

df = pd.read_csv('分词以后的药食同源.csv',encoding = 'utf-8')

ltp = LTP()

# user_dict.txt 是词典文件， max_window是最大前向分词窗口
ltp.init_dict(path="中药大词典合集.txt", max_window=4)
# segment, _ = ltp.seg(["他叫汤姆去拿外衣。"])
# print(segment)
df.describe().T
# Out:
#              count   mean         std  min    25%    50%     75%     max
# Unnamed: 0  1799.0  899.0  519.470885  0.0  449.5  899.0  1348.5  1798.0

# %%
abstract = df.摘要
abstract
# Out:
# 0       中草药是我国文化的瑰宝,中医理论是中国传统医学的核心,其中的许多理念都可以与现代食品工业中的...
# 1       葛根营养丰富,是一种重要的药食同源植物,可开发为多种药用和保健食品,市场前景广阔.综述了葛根...
# 2       目的:分析近十年来药食同源类中药防治冠心病的应用及配伍规律.方法:检索中医临床诊疗文献数据库...
# 3       目的:对不同地域的种药食同源药材中重金属及农药残留进行测定,为药材的安全性评价和监管及相应措...
# 4       建立了加速溶剂萃取-QuEChERS-超高效液相色谱-串联质谱测定药食同源性食品中种真菌毒素...
#                               ...
# 1794    北有人参，南有三七。三七是驰名中外的名贵中药材，也是我国民间最早使用的药食同源植物之一，素有...
# 1795    果桑是专门用来生产优质桑果（桑葚）一类桑树的总称,位列国家卫计委确定并公布的＂既是食品又是药...
# 1796    为了使沙棘提取果汁后的废弃物(沙棘籽渣)得到有效利用,解决黑木耳生产中原材料短缺和传统原材料...
# 1797    <正>枸杞是药食同源植物,传统药物学认为枸杞滋阴补肾、明目、强身健体,现代科学分析枸杞的主要...
# 1798    西洋参是药食同源植物，既是名贵上品中药，又是高级滋补佳品，被卫生部确定为“可用于保健食品的物...
# Name: 摘要, Length: 1799, dtype: object

# %%
def vob ():
    """
    Python 消除换行符一定.replace('\n','').replace('\r','') 
    将词表转化为一个list
    """
    with open ('中药大词典合集.txt','r') as f:
        vocabL = f.readlines() #读取的结果是list 
        vocabSet = []
        for i in vocabL:#删除换行符
            i = i.replace('\n','').replace('\r','').replace('t','')
            vocabSet.append(i)
        f.close()
        return  vocabSet

# %%
vocabSet = vob()
# for b in vocabSet:
#     print(b)

# %%
def cut(abstract):
    c =[]
    for i in abstract:
        segment, _ = ltp.seg([i])#分词
        segment = str(segment).replace('[','').replace(']','').replace("'",'').replace(',','')#消去符号
    #     print(segment)
        l =[]
        for j in segment.split():
    #         print(j)
    #     break
            if j in vocabSet and j !='药食同源' and j not in l :
                l.append(j)
#                 print(j)
        l = str(l).replace('[','').replace(']','').replace("'",'')
        c.append(l)
        l = []
#         break
    return c

# %%
word = cut(abstract)
word
# Out:
# ['黄芪',
#  '葛根',
#  '丹参, 黄芪, 川芎, 红花, 瓜蒌, 甘草, 当归, 桃仁, 人参, 薤白, 桔梗',
#  '铅',
#  '银花, 葛根, 沙棘',
#  '桑叶, 菊花, 黄芪, 青果, 桔梗, 金银花, 藿香, 甘草, 百合',
#  '莱菔子, 山楂, 菊花, 葛根, 决明子, 牡蛎, 木瓜, 佛手, 核桃仁, 昆布',
#  '三七',
#  '蒲公英, 青果, 鱼腥草, 马齿苋, 茯苓, 金银花, 山楂, 罗汉果, 益智仁, 甘草, 鸡内金, 陈皮, 菊花, 莲子, 桔梗, 葛根, 紫苏',
#  '金银花, 菊花, 菊苣, 蒲公英, 甘草, 砂仁, 淡竹叶',
#  '山楂, 茯苓, 决明子',
#  '梨, 树花, 山药, 藕',
#  '葛根, 蒲公英, 桑叶, 决明子, 山楂, 山药, 紫苏, 荷叶, 莱菔子, 薏苡仁, 红曲',
#  '莲子',
#  '菊花, 金银花, 槐花, 银花, 扁豆花',
#  '槲皮',
#  '当归',
#  '花椒, 高良姜, 葡萄, 莱菔子, 樱桃, 番茄, 天麻',
#  '李, 樱桃',
#  '紫苏',
#  '',
#  '',
#  '夏枯草, 蒲公英, 人参',
#  '鱼腥草, 枸杞子, 木瓜, 酸枣仁, 玉竹, 乌梢蛇, 菊花, 肉桂, 铅, 银花',
#  '蒲公英',
#  '五味子, 百合, 地黄, 莲子',
#  '铅, 枸杞, 黄芪',
#  '荠菜',
#  '茯苓',
#  '刺梨, 干姜, 肉桂, 山药, 葡萄籽',
#  '杜仲叶, 杜仲',
#  '丁香, 八角茴香, 刀豆, 小茴香, 小蓟, 山药, 山楂, 马齿苋, 乌梢蛇, 乌梅, 木瓜, 火麻仁, 玉竹, 甘草, 白芷, 白果, 白扁豆, 龙眼肉, 决明子, 百合, 肉豆蔻, 肉桂, 余甘子, 佛手, 杏仁, 沙棘, 牡蛎, 芡实, 花椒, 赤小豆, 阿胶, 鸡内金, 麦芽, 昆布, 大枣, 罗汉果, 郁李仁, 金银花, 青果, 鱼腥草, 生姜, 干姜, 枸杞子, 砂仁, 茯苓, 香橼, 香薷, 桃仁, 桑叶, 橘红, 荷叶, 莱菔子, 高良姜, 淡竹叶, 淡豆豉, 菊花, 菊苣, 芥子, 紫苏, 葛根, 黑芝麻, 槐米, 蒲公英, 蜂蜜, 榧子, 白茅根, 蝮蛇, 橘皮, 薄荷, 薏苡仁, 薤白, 藿香',
#  '丁香, 阿胶, 金银花',
#  '山楂',
#  '铅, 茶叶',
#  '大枣, 蜂蜜, 枸杞',
#  '猪肉',
#  '枸杞',
#  '山药, 山楂, 红枣',
#  '马齿苋',
#  '淮山药, 薏米, 蒲公英, 酸枣仁, 鼠, 淮山',
#  '石蒜, 商陆',
#  '桑叶',
#  '酒, 薄荷',
#  '薏苡仁, 山楂, 大枣, 花椒, 肉桂',
#  '人参, 当归, 大枣, 山楂, 姜黄, 玫瑰花',
#  '黑芝麻, 枸杞, 青果, 山楂, 甘草',
#  '铅',
#  '山楂, 山药, 沙棘, 红枣',
#  '玉, 荞麦',
#  '玉, 熊掌',
#  '甘草, 豆豉, 杏仁, 生姜, 茯苓, 酒',
#  '荞麦',
#  '柠檬, 苦瓜, 李子',
#  '山楂, 余甘子, 牡蛎, 莱菔子, 枸杞子',
#  '蓣, 淮山药, 粘山药',
#  '芜菁',
#  '刀豆',
#  '山药',
#  '大枣',
#  '菊花',
#  '人参',
#  '羊肉',
#  '',
#  '酒, 葛根, 枸杞, 蜂蜜',
#  '冬瓜子',
#  '葱白, 荨麻, 莲子, 白糖, 南瓜, 甘蔗',
#  '余甘子',
#  '沙棘',
#  '茶叶',
#  '海带',
#  '茯苓, 枸杞子, 益智仁, 桃仁, 山药, 石菖蒲, 远志, 川芎, 丹参, 当归, 黄芪',
#  '墨, 茯苓',
#  '葛根',
#  '人参',
#  '铅',
#  '核桃仁, 李',
#  '酒, 锡',
#  '白术',
#  '百合, 枸杞, 牛蒡, 山药, 玉竹, 芦笋',
#  '决明子, 杞子, 荷叶, 桔梗, 蒲公英, 枸杞子',
#  '鹿骨, 鹿胎, 酒, 糯米',
#  '桑叶, 南瓜, 苦瓜, 山药',
#  '玉竹, 百合, 鼠血',
#  '黄精',
#  '豆腐, 铁',
#  '茯苓',
#  '蒲公英, 铁',
#  '牛蒡, 牛蒡子, 东洋参, 牛蒡根, 胡萝卜, 铁',
#  '葡萄, 铁',
#  '荔枝',
#  '铁粉, 乌梅, 青梅',
#  '草果',
#  '山药',
#  '罗勒, 金不换, 罗勒子',
#  '冬虫夏草',
#  '红枣, 粳米, 生姜, 葱白, 芫荽',
#  '黄花菜',
#  '丁香, 八角茴香, 刀豆, 小茴香, 小蓟, 山药, 山楂, 马齿苋, 乌梢蛇, 乌梅, 木瓜, 火麻仁, 玉竹, 甘草, 白芷, 白果, 白扁豆, 龙眼肉, 决明子, 百合, 肉豆蔻, 肉桂, 余甘子, 佛手, 杏仁, 沙棘, 牡蛎, 芡实, 花椒, 赤小豆, 阿胶, 内金, 麦芽, 昆布, 大枣, 罗汉果, 郁李仁, 金银花, 青果, 鱼腥草, 干姜, 枸杞子, 栀子, 砂仁, 茯苓, 香橼, 桃仁, 桑叶, 桑椹, 桔梗, 益智仁, 荷叶, 莱菔子, 莲子, 高良姜, 淡竹叶, 淡豆豉, 菊花, 菊苣, 黄精, 紫苏, 黑芝麻, 槐花, 蒲公英, 蜂蜜, 榧子, 酸枣仁, 蝮蛇, 橘皮, 薄荷, 薏苡仁, 薤白, 覆盆子',
#  '铁, 山药',
#  '枸杞, 枸杞子',
#  '李',
#  '蜂蜜',
#  '石膏, 芒硝, 蝉衣, 地龙',
#  '苦瓜',
#  '大蒜',
#  '金银花',
#  '板蓝根, 马齿苋, 鱼腥草, 紫苏, 蒲公英, 藤三七, 小茴香, 藿香',
#  '薤白',
#  '马齿苋, 蒲公英',
#  '丁香',
#  '铅, 黄芪, 白芍, 甘草, 山楂, 枸杞, 金银花, 银花',
#  '何首乌, 阿胶, 枸杞',
#  '人参',
#  '手参, 手掌参, 生地',
#  '花椒',
#  '党参, 酒, 藜芦',
#  '香菇',
#  '大蒜',
#  '人参',
#  '芦笋, 天门冬',
#  '桑椹, 桑叶, 桑枝, 桑白皮',
#  '何首乌, 枸杞, 人参',
#  '何首乌, 枸杞, 当归, 黄芪, 玉',
#  '唐松草',
#  '鱼腥草',
#  '齐墩果',
#  '酸枣仁',
#  '山药, 玉竹',
#  '内金, 鸡内金',
#  '马齿苋, 蒲公英',
#  '玉',
#  '山栀子, 栀子',
#  '艾叶, 香艾',
#  '芦笋',
#  '黄芪, 党参',
#  '陈皮',
#  '猕猴桃, 李',
#  '山楂, 李',
#  '党参, 肉苁蓉, 石斛, 西洋参, 黄芪, 灵芝, 山茱萸, 天麻, 杜仲叶',
#  '牛大力',
#  '蒲公英',
#  '小麦',
#  '葛根',
#  '杜仲',
#  '枸杞',
#  '生姜, 荆芥, 防风',
#  '黄芪, 黄连, 茯苓, 白术, 大黄, 人参, 牛蒡子',
#  '红花',
#  '薏苡仁, 莲子, 山楂, 荷叶, 白扁豆, 草果, 白果',
#  '白子菜',
#  '',
#  '枸杞子, 枸杞',
#  '麦芽',
#  '薤白',
#  '麻油',
#  '枸杞, 白糖',
#  '芦荟',
#  '益智',
#  '酒, 石斛, 葛根',
#  '山药, 枸杞',
#  '薏米, 薏苡仁',
#  '枸杞, 香菇, 茯苓, 红枣',
#  '胡萝卜, 香菇, 牛蒡',
#  '金樱子',
#  '苦荞麦',
#  '野山楂, 山楂',
#  '黄芪',
#  '鱼腥草',
#  '鼠曲草, 金丝桃',
#  '葱叶',
#  '藜, 杂',
#  '稻草',
#  '丁香, 刀豆, 小茴香, 小蓟, 山药, 山楂, 马齿苋, 乌梢蛇, 乌梅, 木瓜, 火麻仁, 玉竹, 甘草, 白芷, 白果, 白扁豆, 龙眼肉, 决明子, 百合, 肉豆蔻, 肉桂, 余甘子, 佛手, 杏仁, 沙棘, 芡实, 花椒, 阿胶, 鸡内金, 麦芽, 昆布, 大枣, 罗汉果, 郁李仁, 金银花, 青果, 鱼腥草, 干姜, 枸杞子, 栀子, 砂仁, 胖大海, 茯苓, 香橼, 香薷, 桃仁, 桑叶, 桔红, 桔梗, 益智仁, 荷叶, 莱菔子, 莲子, 淡竹叶, 淡豆豉, 菊花, 菊苣, 黄精, 紫苏, 葛根, 黑芝麻, 槐花, 蒲公英, 蜂蜜, 榧子, 酸枣仁, 橘皮, 薄荷, 薏苡仁',
#  '枸杞, 生姜, 红枣',
#  '蘑菇, 冬虫夏草',
#  '木通, 五叶木通, 山木通',
#  '肉桂',
#  '蒲公英, 地丁',
#  '乌梅, 甘草, 陈皮, 山楂, 冰糖',
#  '蝤蛴',
#  '红景天',
#  '大枣, 莲子, 山药, 白扁豆, 山楂, 枸杞子, 金银花, 西洋参',
#  '迷迭香, 樟脑',
#  '燕窝',
#  '蒲公英, 地丁',
#  '茯苓',
#  '半夏, 陈皮, 丹参, 茯苓, 山楂',
#  '当归',
#  '鼠',
#  '甘薯',
#  '车前子',
#  '饴糖',
#  '鸡蛋壳',
#  '胡椒',
#  '紫苏',
#  '人参',
#  '牛蒡子',
#  '酸枣仁',
#  '栀子',
#  '独脚金, 孩儿草, 青天葵, 布渣叶, 鸡蛋花',
#  '酸枣仁, 枸杞',
#  '人参, 龙眼肉, 阿胶, 山楂, 干姜, 蜂蜜',
#  '杂, 大枣, 生姜, 紫苏, 乌梅, 赤小豆, 薏苡仁, 山药',
#  '三七, 人参, 蔗糖',
#  '灵芝',
#  '沙棘, 魔芋',
#  '芡实, 睡莲',
#  '枸杞, 枸杞子, 酸浆',
#  '黑芝麻',
#  '苦瓜',
#  '杂, 猪肉, 棕榈, 豆蔻',
#  '决明子',
#  '花椒',
#  '榆树',
#  '仙人掌',
#  '菊花',
#  '莲子, 银耳, 白果',
#  '芋头, 芋',
#  '山楂',
#  '铁',
#  '西瓜, 西瓜皮, 西瓜翠衣',
#  '佛手, 白果',
#  '荷叶, 鼠',
#  '黄酒, 酒',
#  '木蝴蝶',
#  '益智仁, 益智',
#  '杨树花, 马齿苋, 蒲公英',
#  '大蒜',
#  '青钱柳',
#  '甘草, 烟草',
#  '马齿苋, 马齿, 苋',
#  '丹皮, 金银花, 山楂',
#  '青蒿',
#  '玫瑰花',
#  '枸杞子, 酒',
#  '玉竹, 南瓜, 麦冬, 山药',
#  '海蜇, 醋, 麻油',
#  '肉豆蔻',
#  '三七',
#  '山药, 枸杞, 桑叶, 银杏叶, 桔梗, 丹参, 苏木',
#  '木耳, 山楂, 粳米',
#  '小麦',
#  '桑叶, 桑椹, 桑枝, 桑白皮, 酒',
#  '人参',
#  '莲子, 百合花, 罗汉果, 山楂, 薄荷, 菊花',
#  '藜, 小麦',
#  '咖啡',
#  '葡萄, 鸡肉',
#  '山药, 白砂糖',
#  '花椒, 芸香',
#  '茯苓, 猪苓, 雷丸, 木耳, 灵芝, 天麻',
#  '牛蒡, 山药, 东洋参',
#  '佛手, 山药',
#  '葛根, 酒, 猪肉, 鸡肉, 蘑菇',
#  '苹果',
#  '何首乌, 枸杞, 当归, 玉',
#  '蜂蜜',
#  '菊花',
#  '天麻',
#  '葛根',
#  '龙眼肉, 锡',
#  '茯苓',
#  '人参',
#  '刺龙牙',
#  '藕, 虾, 蟹, 浮萍, 水绵',
#  '小麦',
#  '枸杞',
#  '生姜, 百合',
#  '海带, 海藻',
#  '枸杞',
#  '诃子',
#  '铁, 石斛, 李, 益智',
#  '大青叶, 板蓝根',
#  '大枣, 茯苓, 香菇, 木耳',
#  '大蒜',
#  '锡, 姜黄',
#  '当归, 三七',
#  '锡, 茶叶, 荞麦',
#  '人参, 咖啡, 酒',
#  '牛蒡, 牛蒡根, 牛蒡子',
#  '葛根, 麻叶',
#  '白扁豆, 生藤',
#  '葛根, 杂',
#  '菱, 泥鳅, 人参',
#  '燕窝, 海参, 西洋参, 石斛',
#  '卷心菜, 人参, 鹿茸',
#  '菊花, 金银花, 山楂',
#  '枸杞',
#  '鹿茸, 鹿角, 鹿心, 鹿胎, 鹿骨',
#  '杂, 粳米',
#  '玫瑰花',
#  '沙棘',
#  '山药',
#  '南瓜子, 南瓜, 葫芦',
#  '杏仁',
#  '枸杞子, 酒, 枸杞, 石斛, 铅',
#  '山楂, 苹果, 梨',
#  '海藻, 冬瓜',
#  '槟榔',
#  '山药',
#  '蜂蜜',
#  '燕窝, 银耳, 百合, 梨',
#  '白果',
#  '红枣',
#  '酱, 大蒜, 猪肉, 黄瓜',
#  '白果',
#  '枸杞',
#  '香椿, 柳芽, 甘草, 铁',
#  '山香',
#  '百合, 莲子',
#  '胡桃, 榛子',
#  '白果',
#  '玳瑁',
#  '酒, 蜂蜜',
#  '砒霜, 生姜, 干姜',
#  '玉, 山楂, 木瓜, 苦瓜, 苦菜',
#  '沙棘',
#  '玉, 黄芪',
#  '当归, 枸杞',
#  '大枣, 蘑菇, 香菇, 木耳',
#  '龙眼肉',
#  '三七, 人参',
#  '沙棘, 胡颓子, 人参',
#  '芡实, 鸡头, 睡莲',
#  '葛根, 酒, 猪肉, 鸡肉, 蘑菇',
#  '百合',
#  '罗布麻叶, 山楂, 决明子, 鼠',
#  '白子菜',
#  '杂, 荞麦, 燕麦, 大麦, 高粱',
#  '胡桃',
#  '草果, 豆蔻',
#  '红枣, 大枣, 李, 栗',
#  '苦荞麦, 荞麦',
#  '紫背菜, 三七, 铁',
#  '人参',
#  '茶叶',
#  '枸杞',
#  '醋',
#  '菊花',
#  '酒, 螺蛳, 孜然, 辣椒',
#  '葡萄, 越橘, 草莓, 沙棘, 苹果, 红花',
#  '金银花, 菊花, 枸杞, 柠檬, 甘草',
#  '大枣',
#  '香菇, 茶叶',
#  '芸香',
#  '怀药, 山药',
#  '葛粉, 葛花, 酒',
#  '麦冬, 胡萝卜, 红枣, 山药, 百合',
#  '玉, 人参, 八宝茶',
#  '茶叶',
#  '大枣, 蘑菇, 香菇, 木耳',
#  '鹦, 绿豆, 杂',
#  '草果, 豆蔻',
#  '山药, 锡, 苦瓜, 莲子',
#  '山楂',
#  '茶叶',
#  '蔗糖',
#  '山楂, 野山楂',
#  '葫芦',
#  '山楂, 薏米, 生姜, 肉桂',
#  '侧耳, 茯苓',
#  '白糖, 冰糖, 蜂蜜',
#  '八宝茶, 人参',
#  '薄荷',
#  '花粉',
#  '绿豆, 绿豆芽',
#  '黄芪, 黄花菜',
#  '莲子, 莲房',
#  '山楂, 薏米, 生姜, 肉桂',
#  '铁, 山药, 怀药',
#  '枸杞子, 桑椹子, 红枣, 淮山',
#  '豆腐, 葱白, 淡豆豉, 川贝, 泥鳅, 荠菜',
#  '胡萝卜, 番茄, 西瓜, 红枣, 辣椒, 山楂, 草莓, 羊肉, 猪肉',
#  '蔗糖',
#  '牡蛎',
#  '醋, 高粱, 麸皮, 酱',
#  '醋, 枸杞, 白果, 燕麦, 腐乳, 豆豉',
#  '牡蛎, 牡蛎肉, 蛤蜊, 蛏',
#  '桔梗',
#  '蚕蛹',
#  '香椿, 荔枝',
#  '牡蛎',
#  '菊花',
#  '鹿肉',
#  '大蒜',
#  '桑椹, 桑枝, 桑叶',
#  '冬虫夏草',
#  '桔梗',
#  '无花果',
#  '枸杞, 黑果',
#  '生姜',
#  '枸杞, 枸杞子',
#  '藤三七, 三七, 落葵',
#  '三七',
#  '苦荞麦, 麸皮',
#  '芜荑, 酱, 豆豉',
#  '鱼腥草',
#  '薏苡仁, 玉',
#  '人参',
#  '燕窝, 人参, 海带',
#  '山楂, 山药',
#  '杂, 粳米',
#  '生姜',
#  '竹沥, 粳米',
#  '佛手',
#  '鼠血, 鼠',
#  '鼠肾, 鼠',
#  '干姜, 白芷',
#  '三七, 三七花, 鼠',
#  '水茄',
#  '绞股蓝',
#  '紫苏, 生姜, 花椒',
#  '枸杞, 山楂',
#  '蚕茧',
#  '酒',
#  '猪肉',
#  '苦瓜',
#  '覆盆子',
#  '猪肉',
#  '沙棘, 山核桃, 无花果, 刺梨, 余甘子, 醋栗, 覆盆子, 刺玫果',
#  '柴胡, 龙骨, 桂枝, 干姜, 葛根',
#  '蜜环菌, 罗布麻, 葛根, 鼠',
#  '五指毛桃, 人参',
#  '乌梅, 山楂, 藿香, 菊花, 紫苏, 生姜, 芦根, 白茅根, 甘草, 蜂蜜, 低聚糖',
#  '枸杞, 山楂',
#  '黄精',
#  '慈姑',
#  '酸枣仁, 甘草, 地黄, 桃仁, 当归',
#  '酒',
#  '狼尾草, 回回豆, 白芥子, 苏子, 丝瓜藤, 冰糖, 蜂蜜, 杏仁, 贝母, 甘草, 陈皮, 桑白皮',
#  '苦瓜',
#  '葛花, 陈皮',
#  '决明子',
#  '银杏叶, 金银花, 蒲公英',
#  '罗汉果, 枸杞, 决明子',
#  '刺梨',
#  '枸杞',
#  '灵芝',
#  '山楂',
#  '栀子',
#  '桑叶',
#  '马齿苋',
#  '莼菜, 莼',
#  '草果',
#  '马齿苋',
#  '高粱',
#  '荷叶',
#  '枸杞, 山楂, 红枣, 白砂糖, 麦芽',
#  '芦笋',
#  '葛根, 人参',
#  '菊花',
#  '黄精',
#  '大麦',
#  '草莓',
#  '葛根, 醋, 高粱',
#  '燕窝',
#  '青果',
#  '当归',
#  '山药',
#  '杂, 高粱',
#  '蒲公英',
#  '蒲公英',
#  '黄精',
#  '蜂蜜',
#  '酒, 橘饼, 陈皮, 玫瑰花, 山楂, 生姜',
#  '蒲公英',
#  '滇, 生姜',
#  '丁香, 胡椒, 肉桂',
#  '紫苏, 苏子, 紫苏子',
#  '荞麦',
#  '夏枯草',
#  '莲子',
#  '山药',
#  '玉, 山楂, 薏苡仁, 山药, 莲子, 赤小豆, 黑豆',
#  '山楂, 决明子',
#  '南瓜, 葫芦',
#  '百合, 小麦',
#  '荞麦',
#  '豆蔻, 草豆蔻, 艳山姜',
#  '蒺藜, 刺蒺藜, 白蒺藜',
#  '刀豆',
#  '苍术',
#  '枸杞',
#  '大蒜, 百合',
#  '沙棘',
#  '黄精',
#  '沙棘',
#  '沙参',
#  '豆豉',
#  '草决明, 决明子, 雀',
#  '蜂蜜',
#  '没食子, 芍药, 白芍',
#  '荞麦',
#  '红枣, 杂',
#  '薏苡仁, 麸皮',
#  '覆盆子',
#  '黄芪, 苍术, 连翘, 桔梗, 金银花, 藿香, 贯众, 防风, 甘草',
#  '枸杞',
#  '冬瓜',
#  '醋, 酱, 生姜, 干姜, 炮姜',
#  '人参',
#  '余甘子, 大戟',
#  '五指毛桃, 黄芪, 佛手',
#  '生姜, 杏仁, 木瓜',
#  '毛木耳',
#  '铁',
#  '大枣, 山药, 莲子, 百合, 薏苡仁, 枸杞子',
#  '猕猴桃, 梨, 草莓, 香蕉, 西瓜',
#  '琴叶榕',
#  '龙眼肉, 蔗糖, 铁',
#  '生姜, 透骨草, 三七, 红花, 当归, 牛膝, 甘草, 川芎, 茯苓, 木瓜, 续断, 威灵仙',
#  '银花, 杂',
#  '猕猴桃',
#  '杂, 桑椹',
#  '金樱子',
#  '黄精',
#  '黑果, 枸杞',
#  '毛木耳',
#  '葛根',
#  '海藻, 昆布, 海带, 紫菜',
#  '草果',
#  '人参',
#  '香菇',
#  '绿豆',
#  '马齿苋',
#  '黄精',
#  '枇杷, 枇杷叶',
#  '马齿苋, 杂',
#  '荜茇',
#  '酒, 荠菜',
#  '甘草',
#  '绿豆',
#  '枳实, 薤白, 枳壳',
#  '玉竹, 乌梅, 罗汉果',
#  '茯苓, 陈皮, 山楂, 枸杞',
#  '荜茇, 胡椒',
#  '茯苓',
#  '龙眼肉, 枸杞子, 肉桂, 辣椒, 花椒',
#  '胡桃仁, 益智',
#  '金银花',
#  '鱼腥草, 三白草',
#  '佛手, 香橼',
#  '山药',
#  '鸡肉, 紫苏',
#  '荞麦',
#  '瓦松',
#  '香菇',
#  '咖啡, 酒',
#  '小麦, 菠菜, 凉薯, 百合, 绿豆',
#  '石斛',
#  '紫苏, 亚麻',
#  '人参',
#  '无花果',
#  '人参',
#  '香菇',
#  '葛根',
#  '陈皮, 玫瑰花, 山楂, 生姜',
#  '蒲公英',
#  '山楂, 陈皮, 鼠, 小茴香',
#  '淡豆豉, 豆豉',
#  '桑叶, 桑椹',
#  '黄精',
#  '山茱萸',
#  '鼠',
#  '枸杞',
#  '桂皮',
#  '苦瓜',
#  '金银花',
#  '鼠李, 酒',
#  '酒',
#  '枸杞',
#  '紫苏叶, 马鞭草, 紫苏, 薄荷',
#  '山药, 蓣',
#  '苹果, 柠檬, 樱桃',
#  '红枣',
#  '桑叶, 桑芽',
#  '黄芪',
#  '酒',
#  '杜仲, 杜仲叶',
#  '黄精',
#  '苦瓜, 葫芦, 生藤',
#  '淮山, 葛根',
#  '九香虫',
#  '茶叶',
#  '金银花',
#  '何首乌',
#  '芦笋',
#  '枸杞, 胡萝卜',
#  '沙棘',
#  '生姜',
#  '枸杞',
#  '黄精, 山药, 枸杞, 白砂糖',
#  '没食子',
#  '黄精, 百合, 鸡头',
#  '茯苓',
#  '蒲公英',
#  '太子参, 繁缕',
#  '大蒜',
#  '山药, 大枣, 山楂, 枸杞子, 赤小豆, 莲子, 芡实, 金银花, 藿香, 紫苏, 薄荷',
#  '玉, 鼠',
#  '菊花, 玫瑰花, 金银花, 茉莉花, 金雀花, 槐花',
#  '三七, 鼠',
#  '荞麦',
#  '枸杞',
#  '杜仲, 杜仲叶',
#  '紫菜',
#  '薤白',
#  '荞麦',
#  '树花',
#  '三七',
#  '桑叶',
#  '山楂',
#  '黄精',
#  '芡实, 鸡头',
#  '山药',
#  '猕猴桃, 猕猴桃根',
#  '菊花, 山楂, 酱',
#  '决明子',
#  '菊花',
#  '草果',
#  '香菇, 羊肚菌, 灵芝, 桑黄, 熊掌',
#  '葛根',
#  '酒',
#  '黄精, 杂',
#  '黄精',
#  '葡萄, 鸡肉',
#  '莲子',
#  '八角茴香',
#  '鼠, 花生油',
#  '余甘子',
#  '罗汉果, 蔗糖, 茶叶, 柠檬',
#  '八月瓜, 铁, 儿茶',
#  '茶叶',
#  '蛴螬, 天冬',
#  '黄精',
#  '茯苓, 山药',
#  '百合',
#  '鱼腥草',
#  '松花粉',
#  '黄芪',
#  '杜仲, 甘草, 葛根, 红枣, 蔗糖, 香叶',
#  '大蒜, 百合',
#  '荸荠, 木瓜',
#  '五指毛桃',
#  '枸杞',
#  '蝌蚪',
#  '九香虫',
#  '鸡肉, 铁',
#  '铁, 山药, 蓣, 铁锈, 油茶',
#  '山药',
#  '慈姑, 泽泻, 菰, 泥鳅',
#  '枸杞',
#  '黄精',
#  '红曲',
#  '粳米, 芝麻, 小麦',
#  '荷叶, 莲子心, 荷花, 莲子, 莲房, 藕节, 荷梗, 莲须',
#  '刺五加',
#  '松花粉, 花粉',
#  '毛木耳',
#  '沙棘, 鼠, 酒',
#  '决明子, 白芍, 芦荟, 淫羊藿, 三七, 番泻叶, 红花, 五味子',
#  '桑椹',
#  '香菇, 山药',
#  '甘草',
#  '余甘子, 葡萄, 蔗糖',
#  '滇',
#  '樱桃, 樱桃核',
#  '苦荞麦, 杂',
#  '人参, 凉粉草',
#  '无花果',
#  '黄精',
#  '枸杞子, 枸杞',
#  '迷迭香',
#  '山药',
#  '蒲公英',
#  '菊花, 怀药',
#  '芝麻',
#  '茯苓, 杏仁, 甘草',
#  '紫苏叶',
#  '马铃薯, 明胶',
#  '海藻, 芋头, 海带, 无花果, 大枣, 鼠',
#  '蜂蜜',
#  '生姜, 大枣',
#  '水芹, 人参',
#  '芦笋',
#  '枸杞',
#  '人参, 益智, 红皮',
#  '黄芪',
#  '苦菜',
#  '杂, 茯苓, 熟地, 麦冬, 牡蛎, 痰药, 远志, 酸枣仁, 菖蒲, 谷芽, 生地, 牡丹皮, 地黄, 南沙参, 川贝母, 沙苑子, 南烛子, 巴戟天, 菟丝子, 陈皮, 半夏, 人参, 白术, 甘草, 白芍, 山药, 石斛, 益智',
#  '马乳',
#  '三加, 烟草, 野菰',
#  '玉竹',
#  '松花粉, 花粉',
#  '菊花, 枸杞子',
#  '绞股蓝',
#  '酒, 葛根, 葛花, 丹参, 山楂',
#  '葛根, 芡实, 菊苣',
#  '紫苏, 白苏, 紫苏子',
#  '谷芽, 麦芽, 稻芽',
#  '马齿苋',
#  '樱桃, 铅',
#  '鱼腥草, 侧耳',
#  '牡蛎, 桃仁, 蕨',
#  '沙棘',
#  '枸杞',
#  '白砂糖, 金银花, 夏枯草, 甘草, 菊花, 竹叶, 土茯苓',
#  '酸浆, 番茄, 花粉',
#  '青钱柳',
#  '五味子',
#  '麦冬',
#  '枸杞叶, 胡萝卜, 铁, 枸杞',
#  '马齿苋',
#  '菊花, 陈皮, 百合, 山药, 甘草, 山楂, 冬瓜',
#  '覆盆子',
#  '青稞, 酒, 冬虫夏草, 人参, 黄精',
#  '刺梨, 酒, 梨',
#  '薄荷',
#  '黄精, 百合',
#  '桑叶, 葡萄',
#  '沙芥',
#  '花椒',
#  '益智',
#  '槐角, 生姜, 陈皮, 山药, 薏米, 芡实, 甘草, 黄精, 枸杞, 琥珀',
#  '栀子',
#  '红曲, 蔗糖, 葡萄',
#  '玉, 黄芪',
#  '薏米',
#  '白首乌, 鹅绒藤, 麦芽',
#  '益智仁',
#  '唐松草',
#  '茶叶',
#  '芍药',
#  '茶叶',
#  '菊花',
#  '枸杞, 金银花, 菊花, 三七, 人参, 大枣',
#  '蒲公英',
#  '牛大力',
#  '枸杞, 枸杞子, 铁',
#  '黄精, 百合, 鸡头',
#  '紫苏',
#  '葛藟, 人参',
#  '山药, 柠檬, 酱, 柠檬皮',
#  '燕窝',
#  '辣椒, 酱, 大蒜, 生姜, 木姜子',
#  '栀子, 葡萄',
#  '桃金娘, 丁香',
#  '鼠',
#  '花椒',
#  '鼠李, 酸枣仁',
#  '鼠, 酒',
#  '玫瑰花',
#  '番茄',
#  '燕麦',
#  '睡莲, 莲花, 莲子, 莲子心, 莲房, 藕节, 荷叶, 荷梗',
#  '紫苏, 亚麻, 紫苏叶',
#  '扶桑, 牛蒡',
#  '何首乌, 首乌',
#  '苦瓜, 百合, 薄荷, 石斛, 桔梗, 荆芥',
#  '大麦',
#  '玉, 小麦, 茶叶',
#  '黄精',
#  '沙棘',
#  '肉桂',
#  '党参',
#  '茯苓, 蜂蜜, 蜂蜡, 黑大豆, 松香, 大枣, 火麻仁, 天门冬, 糯米, 侧柏叶, 白术, 黑芝麻, 粳米, 小麦, 人参, 甘草',
#  '桑椹, 桑葚子',
#  '南瓜',
#  '粳米, 米油, 熟地',
#  '桂枝',
#  '马齿苋, 苦菜, 睡莲',
#  '龙牙楤木, 齐墩果',
#  '蒲公英',
#  '毒芹, 松油',
#  '杜仲',
#  '海藻',
#  '紫苏',
#  '',
#  '海马, 人参',
#  '槐花, 樱桃, 柠檬',
#  '草果',
#  '黑芝麻, 芝麻',
#  '黄芪, 党参, 铅, 昆布',
#  '温泉',
#  '大枣',
#  '紫苏, 亚麻, 玉',
#  '海藻',
#  '鼠',
#  '滇, 天麻',
#  '观音苋, 三七, 铁',
#  '杜仲',
#  '茯苓',
#  '黄精',
#  '桔梗',
#  '海藻, 葡萄',
#  '橄榄',
#  '莲子, 杂',
#  '黑果, 枸杞',
#  '海马, 鼠',
#  '凉粉草',
#  '葛根',
#  '桑叶',
#  '黄精',
#  '黄花菜',
#  '无花果',
#  '金耳环, 金钱草',
#  '枸杞, 杂',
#  '蜂蜜, 杂, 生等',
#  '黑果, 枸杞',
#  '五指毛桃',
#  '青钱柳',
#  '枸杞, 玛瑙, 枸杞子, 玉蜀黍',
#  '紫苏',
#  '白芷',
#  '黄精',
#  '葛根',
#  '枸杞',
#  '余甘子',
#  '刺五加, 茶叶',
#  '甘草',
#  '黄精',
#  '菊苣, 葛根, 银花, 蒲公英, 金银花',
#  '茯苓, 白术, 泽泻, 陈皮, 半夏, 山楂, 炙甘草, 大黄, 决明子, 厚朴, 荷叶, 山药',
#  '甘薯',
#  '刺五加',
#  '山药',
#  '怀药, 山药, 牛膝, 菊花',
#  '人参, 西洋参',
#  '绿豆',
#  '杂, 茯神, 白芍, 茯苓, 陈皮, 青蒿, 黄芩, 连翘, 半夏, 郁金, 丹参, 西洋参, 石斛, 白术, 人参, 谷芽, 甘草',
#  '青钱柳',
#  '莱菔子, 豆油',
#  '马齿苋',
#  '酒, 黑豆, 蔓荆子, 黄精, 熟地',
#  '山楂',
#  '山黄皮',
#  '韭菜',
#  '山楂, 花粉',
#  '三七',
#  '苦丁茶, 苦丁',
#  '牛蒡, 牛蒡根',
#  '刺梨',
#  '绿豆, 杂',
#  '黄精',
#  '酱, 麸皮',
#  '人参',
#  '山楂',
#  '构树',
#  '桃金娘, 丁香, 公丁香',
#  '苍术',
#  '百合',
#  '无花果',
#  '枸杞',
#  '薏苡仁',
#  '红花',
#  '人参',
#  '景天',
#  '草豆蔻, 豌豆',
#  '夏枯草, 决明子, 葛根, 山楂, 菊花',
#  '蝙蝠, 猴头菌, 蜜环菌, 灵芝',
#  '葛根',
#  '苦苣',
#  '红枣',
#  '柳叶菜花, 柳叶',
#  '沙棘, 人参',
#  '酒',
#  '苦苣',
#  '鸭, 生姜, 羊肉',
#  '玫瑰花',
#  '桑椹',
#  '菊花脑, 菊花, 菊花叶',
#  '山楂',
#  '枸杞, 枸杞子',
#  '人参, 鹿茸, 阿胶, 三七, 大枣, 蜂蜜, 生姜, 糯米',
#  '芦笋',
#  '沙棘',
#  '猪肺, 铁',
#  '人参, 甘草, 茯苓, 干姜',
#  '酒',
#  '梨',
#  '桔梗, 甘草',
#  '枸杞',
#  '大黄',
#  '对虾',
#  '灵芝',
#  '桔梗',
#  '苍术',
#  '生姜',
#  '橘皮, 枇杷叶, 前胡, 淡豆豉, 生姜, 牛乳, 羊乳, 大枣, 粳米',
#  '花椒, 生姜',
#  '桑叶, 铁扇子, 铁',
#  '山药, 大枣, 山楂, 枸杞子, 赤小豆, 莲子, 芡实, 杂, 金银花, 藿香, 紫苏, 薄荷',
#  '绿豆, 黄瓜, 菠菜, 番石榴, 海带',
#  '杂, 荞麦, 燕麦, 绿豆, 黑豆, 黑芝麻, 莲子, 山药, 红枣, 麦芽, 茯苓, 杏仁, 薏米',
#  '香橼, 芸香, 佛手',
#  '玫瑰花, 酒, 蔗糖',
#  '山姜',
#  '玉竹, 百合, 黄精',
#  '桑椹',
#  '树花',
#  '枸杞',
#  '枸杞',
#  '茶叶, 羊肉',
#  '菊苣',
#  '南酸枣',
#  '海藻',
#  '',
#  '白砂糖, 布渣叶, 菊花, 金银花, 甘草',
#  '红枣',
#  '丁香, 迷迭香, 肉桂, 鼠尾草, 紫苏, 龙虾',
#  '鱼腥草',
#  '菊花',
#  '陈皮, 羊肉, 人参, 当归',
#  '香叶, 藁本',
#  '山楂, 枸杞, 莲子, 菊花, 玫瑰花, 南瓜子',
#  '蚂蚁',
#  '人参, 西洋参, 鹿茸, 阿胶, 三七, 大枣, 蜂蜜',
#  '玫瑰花, 酒, 蔗糖',
#  '荞麦',
#  '栝楼, 葫芦',
#  '石斛, 金银花, 知母, 竹茹',
#  '麦芽, 稻芽',
#  '山茱萸, 胡桃',
#  '绿豆, 附子, 巴豆, 砒霜',
#  '蒲公英',
#  '茶叶',
#  '鸭, 当归, 生姜, 羊肉',
#  '山药, 蓣',
#  '人参, 三七',
#  '枸杞',
#  '阳桃, 酱',
#  '木瓜',
#  '枸杞',
#  '蒲公英, 铁, 山楂',
#  '枸杞, 酒, 附子, 土三七',
#  '灵芝, 山药',
#  '马齿苋, 白砂糖, 蜂蜜, 梨, 蔗糖',
#  '烟草',
#  '香叶, 藁本',
#  '黄芪, 灵芝, 石斛',
#  '百合',
#  '苦瓜',
#  '醋, 杂, 乌梅',
#  '酒',
#  '桔梗',
#  '枸杞',
#  '人参, 当归',
#  '绿豆, 乌头, 附子, 半夏',
#  '人参, 枸杞, 菊花, 牛蒡',
#  '大麦',
#  '葛根',
#  '百合',
#  '百合',
#  '沙棘, 沙棘籽',
#  '温泉',
#  '蒲公英, 杂',
#  '鸡内金, 雉, 内金',
#  '枳实',
#  '刺梨, 没食子, 儿茶',
#  '马齿苋',
#  '桑叶, 芸香',
#  '鱼腥草',
#  '滇, 橄榄',
#  '蘘荷',
#  '沙棘',
#  '桑椹, 荨麻, 铁',
#  '鼠',
#  '黑果, 枸杞',
#  '决明子, 枸杞, 金银花, 白砂糖, 蜂蜜',
#  '红花',
#  '茭白',
#  '山楂',
#  '蒲公英, 铜绿',
#  '糯米, 枸杞, 山药, 覆盆子, 酒',
#  '低聚糖',
#  '玫瑰花',
#  '桑叶, 桑叶汁',
#  '青钱柳, 柳叶',
#  '鸡蛋壳',
#  '槲皮',
#  '决明子, 鼠血, 鼠',
#  '铁, 石斛',
#  '黄精',
#  '荞麦',
#  '桑叶, 咖啡',
#  '白果',
#  '沙棘, 沙枣, 胡颓子',
#  '红景天, 枸杞, 山楂, 蜂蜜, 白砂糖',
#  '五指毛桃',
#  '甘草',
#  '棘胸蛙',
#  '山楂',
#  '山药',
#  '草果',
#  '大枣, 麦芽, 枸杞',
#  '当归',
#  '青钱柳, 柳叶',
#  '鸡肉',
#  '牛蒡, 红枣, 蔗糖',
#  ...]

# %%
word = pd.DataFrame(word)

# %%
df['plt载入词表的分词']= word

# %%
df.to_csv('分词以后的药食同源.csv')
